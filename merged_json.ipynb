# %%
import os
import json
import re

def load_json_safely(file_path):
    """Load JSON from file_path safely, returning a dict or None if failure."""
    if not os.path.isfile(file_path):
        print(f"❌ File not found: {file_path}")
        return None
    try:
        with open(file_path, "r", encoding="utf-8") as f:
            return json.load(f)
    except json.JSONDecodeError as e:
        print(f"❌ Could not decode JSON from {file_path}: {e}")
        return None

def add_emergency_flag(qa_pairs, emergency_keywords):
    """
    For each QA pair in qa_pairs:
      - Ensure its "answer" is stored as a dictionary with keys:
        "main_points", "examples", "tips", and "related_topics".
      - Check the first element of "main_points" (converted to lowercase)
        for any emergency keywords.
      - If a keyword is found, add the flag "is_emergency": true.
    """
    for qa in qa_pairs:
        # If the answer is a plain string, wrap it in a dictionary.
        if isinstance(qa.get("answer"), str):
            qa["answer"] = {
                "main_points": [qa["answer"].strip()],
                "examples": [],
                "tips": [],
                "related_topics": []
            }
        # Get the main text from the first element of main_points (if any)
        main_text = qa["answer"]["main_points"][0].lower() if qa["answer"]["main_points"] else ""
        if any(keyword in main_text for keyword in emergency_keywords):
            qa["is_emergency"] = True

def merge_knowledge_bases(existing_json_path, new_extracted_json_path, merged_json_path):
    # 1. Load existing data
    existing_data = load_json_safely(existing_json_path)
    if existing_data is None:
        print("❌ Aborting: missing or invalid existing knowledge base JSON.")
        return

    # 2. Load new extracted data
    new_data = load_json_safely(new_extracted_json_path)
    if new_data is None:
        print("❌ Aborting: missing or invalid extracted QA JSON.")
        return

    # Define keywords that indicate generic emergency advice.
    emergency_keywords = ["i need help now", "emergency", "urgent", "crisis"]

    # Process existing QA pairs:
    print("🔍 Checking existing QA pairs for emergency keywords...")
    for qa in existing_data.get("qa_pairs", []):
        # Tag existing QA pairs if not already tagged.
        qa.setdefault("source", "existing")
    add_emergency_flag(existing_data.get("qa_pairs", []), emergency_keywords)

    # Process new QA pairs for emergency flag.
    print("🔍 Checking new QA pairs for emergency keywords...")
    for qa in new_data.get("qa_pairs", []):
        print(f"QA question: {qa.get('question')}, answer type: {type(qa.get('answer'))}")
        # Tag new (extracted) QA pairs.
        qa["source"] = "extracted"
    add_emergency_flag(new_data.get("qa_pairs", []), emergency_keywords)

    # 3. Check existing_data structure
    if "categories" not in existing_data or "qa_pairs" not in existing_data:
        print("❌ Error: 'categories' or 'qa_pairs' missing in existing knowledge base.")
        return

    # 4. Check new_data structure
    if "categories" not in new_data or "qa_pairs" not in new_data:
        print("❌ Error: 'categories' or 'qa_pairs' missing in extracted data.")
        return

    # 5. Merge categories (append only those that are new)
    existing_cat_ids = {cat["id"] for cat in existing_data["categories"]}
    for cat in new_data["categories"]:
        cat_id = cat.get("id")
        if cat_id not in existing_cat_ids:
            existing_data["categories"].append(cat)
            existing_cat_ids.add(cat_id)
        else:
            # Optionally merge subcategories here if needed.
            pass

    # 6. Merge QA pairs (append new ones to existing ones)
    new_qa_pairs = new_data.get("qa_pairs", [])
    existing_data["qa_pairs"].extend(new_qa_pairs)

    # 7. Update metadata
    existing_data["metadata"]["topics_count"] = len(existing_data["categories"])
    existing_data["metadata"]["qa_pairs_count"] = len(existing_data["qa_pairs"])

    # 8. Save merged JSON
    try:
        with open(merged_json_path, "w", encoding="utf-8") as f:
            json.dump(existing_data, f, indent=2, ensure_ascii=False)
        print(f"✅ Merged knowledge base saved to: {merged_json_path}")
    except Exception as e:
        print(f"❌ Error saving merged knowledge base: {e}")

if __name__ == "__main__":
    # Example usage: update with your actual file paths
    base_dir = "C:/Users/osato/openai_setup"
    existing_kb_path = os.path.join(base_dir, "knowledge_base.json")
    extracted_kb_path = os.path.join(base_dir, "extracted_structured.json")
    merged_output_path = os.path.join(base_dir, "merged_knowledge_base.json")

    merge_knowledge_bases(
        existing_json_path=existing_kb_path,
        new_extracted_json_path=extracted_kb_path,
        merged_json_path=merged_output_path
    )
# Out:
# 🔍 Checking existing QA pairs for emergency keywords...
# 🔍 Checking new QA pairs for emergency keywords...
# QA question: What is this document about?, answer type: <class 'dict'>
# QA question: Who are Student Minds, NUS, and Universities UK?, answer type: <class 'dict'>
# QA question: Why was this report created?, answer type: <class 'dict'>
# QA question: Who authored this report and who funded it?, answer type: <class 'dict'>
# QA question: How was the Student Perspectives Questionnaire (SPQ) conducted?, answer type: <class 'dict'>
# QA question: What is the Student Voice Forum (SVF)?, answer type: <class 'dict'>
# QA question: Who participated in the Student Voice Forum?, answer type: <class 'dict'>
# QA question: Were participants satisfied with the Student Voice Forum?, answer type: <class 'dict'>
# QA question: Why do students think it is important to talk about mental health?, answer type: <class 'dict'>
# QA question: How do students define "mental health"?, answer type: <class 'dict'>
# QA question: How do students feel about mental health at university?, answer type: <class 'dict'>
# QA question: What do students say could help prevent mental health issues?, answer type: <class 'dict'>
# QA question: How does academic life impact mental health?, answer type: <class 'dict'>
# QA question: Where do students seek mental health support?, answer type: <class 'dict'>
# QA question: What do students expect universities to provide?, answer type: <class 'dict'>
# QA question: What have students found most helpful in practice?, answer type: <class 'dict'>
# QA question: What about advocacy or care coordination?, answer type: <class 'dict'>
# QA question: Do students value peer support and social networks?, answer type: <class 'dict'>
# QA question: How do NHS services fit into the picture?, answer type: <class 'dict'>
# QA question: What stops students from seeking or continuing support?, answer type: <class 'dict'>
# QA question: What do students want in an ideal university culture?, answer type: <class 'dict'>
# QA question: What are the key suggestions from the Student Voice Forum?, answer type: <class 'dict'>
# QA question: How does Student Minds plan to keep student voices engaged?, answer type: <class 'dict'>
# QA question: Where can I learn more?, answer type: <class 'dict'>
# QA question: How was the Student Voice Forum structured?, answer type: <class 'dict'>
# QA question: What specific activities took place in the Student Voice Forum?, answer type: <class 'dict'>
# QA question: Any final notes on this project?, answer type: <class 'dict'>
# QA question: What information do I need for my enrolment task?, answer type: <class 'dict'>
# QA question: The course details in my enrolment task are wrong—what do I do?, answer type: <class 'dict'>
# QA question: I’ve received an enrolment reminder—what should I do?, answer type: <class 'dict'>
# QA question: I missed my enrolment deadline and the task is asking about late enrolment—what does this mean?, answer type: <class 'dict'>
# QA question: I need to complete the identity check—what do I do?, answer type: <class 'dict'>
# QA question: I didn’t enrol onto my course and missed the late enrolment task—what do I do?, answer type: <class 'dict'>
# QA question: The Fees section says my fees are “Home”—what does that mean?, answer type: <class 'dict'>
# QA question: What is the confirmation part of the enrolment task?, answer type: <class 'dict'>
# QA question: When am I required to complete the enrolment task?, answer type: <class 'dict'>
# QA question: I have been contacted by Profile Advantage—who are they?, answer type: <class 'dict'>
# QA question: Where can I get technical support with my DBS applications?, answer type: <class 'dict'>
# QA question: How do I check in for my sessions?, answer type: <class 'dict'>
# QA question: What do I need to do before I can view my timetable?, answer type: <class 'dict'>
# QA question: Do I have to attend Welcome Week activities?, answer type: <class 'dict'>
# QA question: What is an extension?, answer type: <class 'dict'>
# QA question: What is the difference between an evidence-based extension and a self-certification extension?, answer type: <class 'dict'>
# QA question: Where can I apply for an extension?, answer type: <class 'dict'>
# QA question: When can I apply for an extension?, answer type: <class 'dict'>
# QA question: Are there times when I cannot make an extension claim?, answer type: <class 'dict'>
# QA question: Which types of assessments can extensions apply to?, answer type: <class 'dict'>
# QA question: What evidence do I need for my extension claim to be granted?, answer type: <class 'dict'>
# QA question: How long will it take to get a decision on my extension claim?, answer type: <class 'dict'>
# QA question: The assessment I wish to apply for extension for is not showing—what do I do?, answer type: <class 'dict'>
# QA question: My deadline has passed, but I still haven’t received a decision regarding my extension claim—what do I do?, answer type: <class 'dict'>
# QA question: I applied for an evidence-based extension but would prefer a self-certification extension. Can this be changed?, answer type: <class 'dict'>
# QA question: I have an automatic 7-day extension through my Tutor Awareness Sheet (TAS). What does this mean?, answer type: <class 'dict'>
# QA question: If I have a TAS extension, can I apply for another extension?, answer type: <class 'dict'>
# QA question: If I submit my work late with no extension, what happens?, answer type: <class 'dict'>
# QA question: My claim has been set to pending—what does this mean?, answer type: <class 'dict'>
# QA question: Where can I find more information about extenuating circumstances and extensions at the University of Wolverhampton?, answer type: <class 'dict'>
# QA question: What is Data Science?, answer type: <class 'dict'>
# QA question: What is Artificial Intelligence?, answer type: <class 'dict'>
# QA question: How do Data Science and Artificial Intelligence overlap?, answer type: <class 'dict'>
# QA question: Do I need prior maths or programming experience for these conversion MSc courses?, answer type: <class 'dict'>
# QA question: What are the general entry requirements?, answer type: <class 'dict'>
# QA question: What is the course duration and start dates?, answer type: <class 'dict'>
# QA question: Is there a dissertation requirement?, answer type: <class 'dict'>
# QA question: What are Nursing degrees at the University of Wolverhampton?, answer type: <class 'dict'>
# QA question: What are some popular undergraduate Nursing courses?, answer type: <class 'dict'>
# QA question: What Nursing postgraduate courses are available?, answer type: <class 'dict'>
# QA question: What Cyber Security postgraduate courses are available?, answer type: <class 'dict'>
# QA question: How do I contact the Admissions Team?, answer type: <class 'dict'>
# QA question: How are assessments categorized?, answer type: <class 'dict'>
# QA question: Why is my deadline showing a wrong date?, answer type: <class 'dict'>
# QA question: Why are assessment deadlines not showing for one or more modules?, answer type: <class 'dict'>
# QA question: What other items are shown in assessment deadlines?, answer type: <class 'dict'>
# QA question: What assessment deadlines are displayed?, answer type: <class 'dict'>
# QA question: Who do I contact if timetables are incorrect or missing?, answer type: <class 'dict'>
# QA question: How do I contact Faculty Student Services?, answer type: <class 'dict'>
# QA question: What does the BSc Cybersecurity program offer?, answer type: <class 'dict'>
# QA question: What are the industry and employment prospects for BSc Cybersecurity graduates?, answer type: <class 'dict'>
# QA question: What happens during the BSc Cybersecurity course?, answer type: <class 'dict'>
# QA question: What is the MSc Cyber Security program?, answer type: <class 'dict'>
# QA question: What are the key details of the MSc Cyber Security program?, answer type: <class 'dict'>
# QA question: How is the MSc Cyber Security course delivered?, answer type: <class 'dict'>
# QA question: What is the MSc Artificial Intelligence (AI) program?, answer type: <class 'dict'>
# QA question: What are the key details of the MSc Artificial Intelligence program?, answer type: <class 'dict'>
# QA question: Why choose the MSc Artificial Intelligence program?, answer type: <class 'dict'>
# QA question: What is the structure of the MSc Artificial Intelligence course?, answer type: <class 'dict'>
# QA question: What are the entry requirements for the MSc Artificial Intelligence program?, answer type: <class 'dict'>
# QA question: What is the MSc Data Science conversion course about?, answer type: <class 'dict'>
# QA question: What are the key details of the MSc Data Science program?, answer type: <class 'dict'>
# QA question: Why choose the MSc Data Science course?, answer type: <class 'dict'>
# QA question: What modules are included in the MSc Data Science course?, answer type: <class 'dict'>
# QA question: What are the entry requirements for the MSc Data Science course?, answer type: <class 'dict'>
# QA question: Where can international applicants find more information about qualification equivalency?, answer type: <class 'dict'>
# QA question: How do I apply for an extension at the University of Wolverhampton?, answer type: <class 'dict'>
# QA question: How do I apply for an extension? (Step-by-Step), answer type: <class 'dict'>
# QA question: What are the extension options?, answer type: <class 'dict'>
# QA question: When should I apply for an extension?, answer type: <class 'dict'>
# QA question: What are some tips for managing stress as a student?, answer type: <class 'dict'>
# QA question: What are some additional strategies for managing academic stress?, answer type: <class 'dict'>
# QA question: What are some suggestions for managing time better and overcoming procrastination?, answer type: <class 'dict'>
# QA question: Where can a university data science student find internships?, answer type: <class 'dict'>
# QA question: Can you provide links to university partners that help with internships?, answer type: <class 'dict'>
# QA question: Are artificial intelligence students at the University of Wolverhampton eligible for internships?, answer type: <class 'dict'>
# QA question: Are University of Wolverhampton Artificial Intelligence and Data Science Masters students mandated to do an internship?, answer type: <class 'dict'>
# QA question: What are the key points about internships for AI and Data Science students?, answer type: <class 'dict'>
# QA question: What internship opportunities are available as part of the course?, answer type: <class 'dict'>
# QA question: Where can I find more information about internship opportunities?, answer type: <class 'dict'>
# QA question: How can I get a job as a student at the University of Wolverhampton?, answer type: <class 'dict'>
# QA question: Are there student jobs at the University of Wolverhampton?, answer type: <class 'dict'>
# QA question: Can you provide the contact details for counselling services at the University of Wolverhampton?, answer type: <class 'dict'>
# QA question: What information is available about chaplaincy at the University of Wolverhampton?, answer type: <class 'dict'>
# QA question: How can I contact the Chaplaincy?, answer type: <class 'dict'>
# QA question: How can I improve concentration in class?, answer type: <class 'dict'>
# QA question: What are some suggestions for managing time better and overcoming procrastination?, answer type: <class 'dict'>
# QA question: Where can I find study materials or resources at the University of Wolverhampton?, answer type: <class 'dict'>
# QA question: My dissertation deadline is close and it is causing me stress. What should I do?, answer type: <class 'dict'>
# QA question: How do I apply for an extenuating circumstances claim at the University of Wolverhampton?, answer type: <class 'dict'>
# QA question: When should I apply for an extenuating circumstances claim?, answer type: <class 'dict'>
# QA question: What evidence should I provide for an extenuating circumstances claim?, answer type: <class 'dict'>
# QA question: What happens after I apply for an extenuating circumstances claim?, answer type: <class 'dict'>
# QA question: Where can I get further information about extenuating circumstances claims?, answer type: <class 'dict'>
# QA question: How do I help a friend who is in need and depressed at school?, answer type: <class 'dict'>
# QA question: How can I get a job as a student at the University of Wolverhampton?, answer type: <class 'dict'>
# QA question: Are there student jobs available at the University of Wolverhampton?, answer type: <class 'dict'>
# QA question: What support is available for health and wellbeing at the University of Wolverhampton?, answer type: <class 'dict'>
# QA question: How do I register with the MHW Team?, answer type: <class 'dict'>
# QA question: What should I do if I need immediate help?, answer type: <class 'dict'>
# QA question: What is WLV Student Life Connect?, answer type: <class 'dict'>
# QA question: What mental health app can help reduce anxiety and stress?, answer type: <class 'dict'>
# QA question: How can I improve my concentration in class?, answer type: <class 'dict'>
# QA question: What are some suggestions for managing time better and overcoming procrastination?, answer type: <class 'dict'>
# QA question: What is this resource about?, answer type: <class 'dict'>
# QA question: Why is friendship so important for mental health at university?, answer type: <class 'dict'>
# QA question: How can I start a conversation if I’m worried about a friend?, answer type: <class 'dict'>
# QA question: What if I want to open up to a friend about my own struggles?, answer type: <class 'dict'>
# QA question: How can we keep up the fun stuff together?, answer type: <class 'dict'>
# QA question: What if my friend’s mood or behavior becomes difficult to cope with?, answer type: <class 'dict'>
# QA question: What should I do if my friend wants to leave university?, answer type: <class 'dict'>
# QA question: How can I look after myself while supporting a friend?, answer type: <class 'dict'>
# QA question: Are there any student stories that highlight these ideas?, answer type: <class 'dict'>
# QA question: What are some tips for freshers?, answer type: <class 'dict'>
# QA question: How can a friend prepare for university holidays?, answer type: <class 'dict'>
# QA question: How can I help someone manage revision and coursework stress?, answer type: <class 'dict'>
# QA question: What about supporting a friend facing graduation or transitioning out of university?, answer type: <class 'dict'>
# QA question: How can I help a friend with an Eating Disorder?, answer type: <class 'dict'>
# QA question: What should I know about Depression?, answer type: <class 'dict'>
# QA question: What is Bipolar and how can I support someone with it?, answer type: <class 'dict'>
# QA question: How to support a friend with OCD?, answer type: <class 'dict'>
# QA question: What is Psychosis and how should I respond?, answer type: <class 'dict'>
# QA question: What if a friend has Anxiety?, answer type: <class 'dict'>
# QA question: What if my friend is in crisis right now?, answer type: <class 'dict'>
# QA question: Where else can we go for help?, answer type: <class 'dict'>
# QA question: How else can I get involved in supporting mental health at university?, answer type: <class 'dict'>
# QA question: Is there a final message for students supporting friends or dealing with difficulties themselves?, answer type: <class 'dict'>
# QA question: Why can adjusting to a new culture be both exciting and challenging?, answer type: <class 'dict'>
# QA question: How can I embrace open-mindedness?, answer type: <class 'dict'>
# QA question: Why should I learn the local language?, answer type: <class 'dict'>
# QA question: How do I become aware of cultural norms and etiquette?, answer type: <class 'dict'>
# QA question: What are the benefits of participating in cultural activities?, answer type: <class 'dict'>
# QA question: How can I build a support network in a new country?, answer type: <class 'dict'>
# QA question: Why is maintaining a connection with home important?, answer type: <class 'dict'>
# QA question: How do I stay positive and patient during cultural adjustment?, answer type: <class 'dict'>
# QA question: When should I seek support services?, answer type: <class 'dict'>
# QA question: How can I be culturally sensitive and adaptable?, answer type: <class 'dict'>
# QA question: Why is taking care of my mental health important?, answer type: <class 'dict'>
# QA question: How do I make the most of my time abroad?, answer type: <class 'dict'>
# QA question: What is the key takeaway?, answer type: <class 'dict'>
# QA question: Why should I make studying fun?, answer type: <class 'dict'>
# QA question: How can music improve my study sessions?, answer type: <class 'dict'>
# QA question: Why is finding a study buddy helpful?, answer type: <class 'dict'>
# QA question: Does comfortable clothing really make a difference?, answer type: <class 'dict'>
# QA question: How can new pens and pencils motivate me?, answer type: <class 'dict'>
# QA question: What are ways to make my notes look amazing?, answer type: <class 'dict'>
# QA question: How can I turn study time into a fun challenge?, answer type: <class 'dict'>
# QA question: Why should I break up my study time with other activities?, answer type: <class 'dict'>
# QA question: Are there apps that make studying more enjoyable?, answer type: <class 'dict'>
# QA question: Can YouTube videos help me understand tough topics?, answer type: <class 'dict'>
# QA question: Why use old-school flashcards?, answer type: <class 'dict'>
# QA question: Are there flexible online degree programs to consider?, answer type: <class 'dict'>
# QA question: What’s the main takeaway?, answer type: <class 'dict'>
# QA question: What is a placement?, answer type: <class 'dict'>
# QA question: What will I be doing in a placement?, answer type: <class 'dict'>
# QA question: What are the benefits of doing a placement?, answer type: <class 'dict'>
# QA question: Where can I do a placement?, answer type: <class 'dict'>
# QA question: Where are placements advertised?, answer type: <class 'dict'>
# QA question: What work placements and internships does the University offer?, answer type: <class 'dict'>
# QA question: What about overseas placements/internships?, answer type: <class 'dict'>
# QA question: What virtual opportunities are available?, answer type: <class 'dict'>
# QA question: What about volunteering opportunities?, answer type: <class 'dict'>
# QA question: What are summer internships?, answer type: <class 'dict'>
# QA question: What should I do if I am interested in a work placement or internship?, answer type: <class 'dict'>
# QA question: What opportunities are available in AI and Data Science?, answer type: <class 'dict'>
# QA question: What is open day at University of Wolverhampton?, answer type: <class 'dict'>
# QA question: Is it worth going to university open days?, answer type: <class 'dict'>
# QA question: When should I start looking for universities?, answer type: <class 'dict'>
# QA question: Can parents go to university open days?, answer type: <class 'dict'>
# QA question: Who can use our careers appointment services?, answer type: <class 'dict'>
# QA question: How do I book a careers interview?, answer type: <class 'dict'>
# QA question: What happens during a careers appointment?, answer type: <class 'dict'>
# QA question: How is confidentiality and impartiality maintained in careers appointments?, answer type: <class 'dict'>
# QA question: What alternative sources of careers advice are available?, answer type: <class 'dict'>
# QA question: What does the Career SPACE Disclaimer state?, answer type: <class 'dict'>
# QA question: What careers support do current students receive?, answer type: <class 'dict'>
# QA question: What is CV360?, answer type: <class 'dict'>
# QA question: What support is available for recently graduated students?, answer type: <class 'dict'>
# QA question: What should I do if I need help with job applications and interviews?, answer type: <class 'dict'>
# QA question: What is a student ambassador?, answer type: <class 'dict'>
# QA question: Who are the student ambassadors?, answer type: <class 'dict'>
# QA question: What is the application process for becoming a student ambassador?, answer type: <class 'dict'>
# QA question: What happens after you complete the training?, answer type: <class 'dict'>
# QA question: Where can I apply for the Student Ambassador Scheme?, answer type: <class 'dict'>
# QA question: When are the assessment and training dates for the Student Ambassador Scheme?, answer type: <class 'dict'>
# QA question: What is the University Chaplaincy?, answer type: <class 'dict'>
# QA question: What additional support does the Chaplaincy provide?, answer type: <class 'dict'>
# QA question: What facilities are available on campus for prayer and reflection?, answer type: <class 'dict'>
# QA question: What is the "Light a Candle" initiative?, answer type: <class 'dict'>
# QA question: What is Hope Support Services?, answer type: <class 'dict'>
# QA question: Why is leaving home so challenging when someone at home is ill?, answer type: <class 'dict'>
# QA question: What if I’m unsure about leaving home now?, answer type: <class 'dict'>
# QA question: How can I prepare if I do decide to move away?, answer type: <class 'dict'>
# QA question: What are some tips for living away from home when someone is ill?, answer type: <class 'dict'>
# QA question: How do I take care of myself while studying away?, answer type: <class 'dict'>
# QA question: How do I handle responsibilities I used to have at home?, answer type: <class 'dict'>
# QA question: What happens when I visit home?, answer type: <class 'dict'>
# QA question: How can I stay positive despite the challenges?, answer type: <class 'dict'>
# QA question: What final advice do students Naomi and Mel offer?, answer type: <class 'dict'>
# QA question: How can Hope Support Services help?, answer type: <class 'dict'>
# QA question: Any final thoughts?, answer type: <class 'dict'>
# QA question: Why can adjusting to a new culture be both exciting and challenging?, answer type: <class 'dict'>
# QA question: How can I embrace open-mindedness?, answer type: <class 'dict'>
# QA question: Why should I learn the local language?, answer type: <class 'dict'>
# QA question: How do I become aware of cultural norms and etiquette?, answer type: <class 'dict'>
# QA question: What are the benefits of participating in cultural activities?, answer type: <class 'dict'>
# QA question: How can I build a support network in a new country?, answer type: <class 'dict'>
# QA question: Why is maintaining a connection with home important?, answer type: <class 'dict'>
# QA question: How do I stay positive and patient during cultural adjustment?, answer type: <class 'dict'>
# QA question: When should I seek support services?, answer type: <class 'dict'>
# QA question: How can I be culturally sensitive and adaptable?, answer type: <class 'dict'>
# QA question: Why is taking care of my mental health important?, answer type: <class 'dict'>
# QA question: How do I make the most of my time abroad?, answer type: <class 'dict'>
# QA question: What is the key takeaway?, answer type: <class 'dict'>
# QA question: Why is cultural adjustment important?, answer type: <class 'dict'>
# QA question: What are common cultural adjustments?, answer type: <class 'dict'>
# QA question: How can I manage cultural differences effectively?, answer type: <class 'dict'>
# QA question: What support resources are available?, answer type: <class 'dict'>
# QA question: What is the takeaway?, answer type: <class 'dict'>
# QA question: What does culture shock mean?, answer type: <class 'dict'>
# QA question: Why does culture shock happen?, answer type: <class 'dict'>
# QA question: What is the "W" curve model of culture shock?, answer type: <class 'dict'>
# QA question: How can I recognize that my feelings are normal?, answer type: <class 'dict'>
# QA question: How do I balance staying in touch with home?, answer type: <class 'dict'>
# QA question: How can I maintain my well-being day to day?, answer type: <class 'dict'>
# QA question: How do I build a support network?, answer type: <class 'dict'>
# QA question: Are there university services that can help?, answer type: <class 'dict'>
# QA question: Can student societies help me settle in?, answer type: <class 'dict'>
# QA question: Why should I talk to someone rather than isolating myself?, answer type: <class 'dict'>
# QA question: Are there any positive aspects to culture shock?, answer type: <class 'dict'>
# QA question: Why should I apply early for my course, funding, and DSA?, answer type: <class 'dict'>
# QA question: Who can help me if I have a disability or specific learning difficulty?, answer type: <class 'dict'>
# QA question: What happens after I apply to study at the university?, answer type: <class 'dict'>
# QA question: What general support can all students access?, answer type: <class 'dict'>
# QA question: What additional support might be available for students with disabilities or specific learning difficulties?, answer type: <class 'dict'>
# QA question: What are Disabled Students’ Allowances (DSA)?, answer type: <class 'dict'>
# QA question: How do I contact the Student Support and Wellbeing Team?, answer type: <class 'dict'>
# QA question: What are the steps to disclose my disability or specific learning difficulty?, answer type: <class 'dict'>
# QA question: How do I apply for the Disabled Students’ Allowances (DSA)?, answer type: <class 'dict'>
# QA question: What happens if my DSA application is approved?, answer type: <class 'dict'>
# QA question: Do I need to contact the university before applying for DSA?, answer type: <class 'dict'>
# QA question: What if I applied to a University Partnership College?, answer type: <class 'dict'>
# QA question: What if I am not eligible for DSA?, answer type: <class 'dict'>
# QA question: Are EU or international students eligible for DSA?, answer type: <class 'dict'>
# QA question: What if I need personal care while studying?, answer type: <class 'dict'>
# QA question: How is my information kept confidential?, answer type: <class 'dict'>
# QA question: What do I do if I want to apply for additional DSA support or change my provider?, answer type: <class 'dict'>
# QA question: Where can I find more information or alternative formats of this guide?, answer type: <class 'dict'>
# QA question: What is a Tutor Awareness Sheet (TAS)?, answer type: <class 'dict'>
# QA question: I have a disability and I don't know where to go for support, answer type: <class 'dict'>
# QA question: Are wellbeing services free of charge to access?, answer type: <class 'dict'>
# QA question: What support is available to help me study at Wolves?, answer type: <class 'dict'>
# QA question: What is referencing?, answer type: <class 'dict'>
# QA question: What is plagiarism and how can I avoid it?, answer type: <class 'dict'>
# QA question: How can I develop my study skills?, answer type: <class 'dict'>
# QA question: What is an Academic Coach?, answer type: <class 'dict'>
# QA question: How long will it take the NHS Learning Support Fund (LSF) to process an additional funding request or change of circumstances notification?, answer type: <class 'dict'>
# QA question: What is the NHS Learning Support Fund (LSF)?, answer type: <class 'dict'>
# QA question: What are extenuating circumstances?, answer type: <class 'dict'>
# QA question: Where can I apply for extenuating circumstances?, answer type: <class 'dict'>
# QA question: When can I apply for extenuating circumstances?, answer type: <class 'dict'>
# QA question: For which assessments can I apply for extenuating circumstances?, answer type: <class 'dict'>
# QA question: Can I apply for Extenuating Circumstances for modules involving placement learning or practical assessments?, answer type: <class 'dict'>
# QA question: The assessment I wish to apply for is not showing. What do I do?, answer type: <class 'dict'>
# QA question: What evidence do I need for my extenuating circumstances claim to be granted?, answer type: <class 'dict'>
# QA question: I am known to the University's Mental Health and Wellbeing Team. Can they write a letter of support for my Extenuating Circumstances claim?, answer type: <class 'dict'>
# QA question: I have a disclosed disability and receive support/adjustments. Can I use my disability as a reason for Extenuating Circumstances?, answer type: <class 'dict'>
# QA question: How long does it take to get a decision on my extenuating circumstances claim?, answer type: <class 'dict'>
# QA question: My deadline has passed, but I still haven't received a decision. What do I do?, answer type: <class 'dict'>
# QA question: My deadline has passed, but I did not make a claim. Can I still do this?, answer type: <class 'dict'>
# QA question: My claim is set to pending. What does this mean?, answer type: <class 'dict'>
# QA question: My claim has been declined. Can I appeal this decision?, answer type: <class 'dict'>
# QA question: I have been granted extenuating circumstances but still wish to submit my work. Can I do this?, answer type: <class 'dict'>
# QA question: I am an LPC student and want information on applying for extenuating circumstances. Who can I speak to?, answer type: <class 'dict'>
# QA question: I have previously applied for extenuating circumstances. Can I apply again?, answer type: <class 'dict'>
# QA question: What is time management?, answer type: <class 'dict'>
# QA question: Why is time management important?, answer type: <class 'dict'>
# QA question: How can I track my time effectively?, answer type: <class 'dict'>
# QA question: How do I plan ahead for the semester?, answer type: <class 'dict'>
# QA question: Why should I prioritize tasks?, answer type: <class 'dict'>
# QA question: What does it mean to study smart?, answer type: <class 'dict'>
# QA question: How do I time-plan an assignment?, answer type: <class 'dict'>
# QA question: Why should I take regular breaks?, answer type: <class 'dict'>
# QA question: Where can I get more help and advice?, answer type: <class 'dict'>
# QA question: How do I cite this guide?, answer type: <class 'dict'>
# ✅ Merged knowledge base saved to: C:/Users/osato/openai_setup\merged_knowledge_base.json

# %%
import json
import os
import time
from openai import OpenAI
from pinecone import Pinecone

# Load environment variables
from dotenv import load_dotenv
load_dotenv()

OPENAI_API_KEY = os.getenv("OPENAI_API_KEY")
PINECONE_API_KEY = os.getenv("PINECONE_API_KEY")
PINECONE_ENV = os.getenv("PINECONE_ENV")

client = OpenAI(api_key=OPENAI_API_KEY)
pc = Pinecone(api_key=PINECONE_API_KEY, environment=PINECONE_ENV)
index = pc.Index("ai-powered-chatbot")

# Path to merged knowledge base
MERGED_JSON_PATH = "C:/Users/osato/openai_setup/merged_knowledge_base.json"

if not os.path.isfile(MERGED_JSON_PATH):
    raise FileNotFoundError("❌ Merged knowledge base file not found.")

# Load merged knowledge base
with open(MERGED_JSON_PATH, "r", encoding="utf-8") as f:
    knowledgebase = json.load(f)

qa_pairs = knowledgebase.get("qa_pairs", [])
print(f"✅ Loaded {len(qa_pairs)} QA pairs from merged file.")

# Re-index the knowledge base
def index_qa_pairs(pairs):
    for idx, qa in enumerate(pairs):
        question = qa.get("question", "").strip()

        # Ensure "main_points" is a list and join its elements into a single string
        answer_list = qa.get("answer", {}).get("main_points", [])
        if isinstance(answer_list, list):
            answer = " ".join(answer_list).strip()
        else:
            answer = str(answer_list).strip()  # Handle unexpected cases

        full_text = f"Q: {question}\nA: {answer}"

        # Generate embeddings
        response = client.embeddings.create(
            model="text-embedding-ada-002",
            input=full_text
        )
        vector = response.data[0].embedding
        
        index.upsert([
    {
        "id": f"qa_{idx}",
        "values": vector,
        "metadata": {
            "question": question,
            "answer": answer
        }
    }
    ],)

        time.sleep(0.1)  # Avoid hitting rate limits

print("🔄 Re-indexing QA pairs...")
index_qa_pairs(qa_pairs)
print("✅ Pinecone index updated.")
# Out:
# ✅ Loaded 470 QA pairs from merged file.
# 🔄 Re-indexing QA pairs...
# ✅ Pinecone index updated.
